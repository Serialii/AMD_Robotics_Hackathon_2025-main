# %% [markdown]
# # Train Models Using LeRobot on MI300x
#
# This guide walks you through setting up environment for training imitation learning policies using LeRobot library on a DigitalOcean (DO) instance equipped with AMD MI300x GPUs and ROCm.
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=${HF_USER}/${DATASET_NAME}`).
#   If you don’t have an access token yet, you can sign up for Hugging Face [here](https://huggingface.co/join). After signing up, create an access token by visiting [here](https://huggingface.co/settings/tokens).
# - A wandb account to enable training visualization and upload your training evidence to our github.
#   You can sign up for Wandb [here](https://wandb.ai/signup) and visit [here](https://wandb.ai/authorize) to create a token.
# - Access to DO instance AMD Mi300x GPU

# %% [markdown]
# ## Verify ROCm and GPU availability
# This cell uses `pytorch` to check AMD GPU Info. The expected ouput is
# ```
# CUDA compatible device availability: True
# device name [0]: AMD Instinct MI300X VF
# ```

# %%
import torch
print(f'CUDA compatible device availability:',torch.cuda.is_available())
print(f'device name [0]:', torch.cuda.get_device_name(0))
# Out:
# CUDA compatible device availability: True
# device name [0]: AMD Instinct MI300X VF

# %% [markdown]
# ## Install FFmpeg 7.x
# This cell uses `apt` to install ffmpeg 7.x for LeRobot.

# %%
# !add-apt-repository ppa:ubuntuhandbook1/ffmpeg7 -y # install PPA which contains ffmpeg 7.x
# !apt update && apt install ffmpeg -y
# Out:
# Repository: 'Types: deb
# URIs: https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu/
# Suites: noble
# Components: main
# '
# Description:
# unofficial build for FFmpeg 7 for Ubuntu 22.04 | 24.04, backport from Debian's deb.multimedia.org repository
#
# If the packages here are helpful, you may buy me a coffee:
#
#          https://ko-fi.com/ubuntuhandbook1
# More info: https://launchpad.net/~ubuntuhandbook1/+archive/ubuntu/ffmpeg7
# Adding repository.
# Found existing deb entry in /etc/apt/sources.list.d/ubuntuhandbook1-ubuntu-ffmpeg7-noble.sources
# Hit:1 https://repo.radeon.com/amdgpu/30.10/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:3 https://repo.radeon.com/rocm/apt/7.0 jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Hit:5 https://repo.radeon.com/graphics/7.0/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:7 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [2118 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Components [235 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [1944 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Components [520 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Components [160 B]
# Get:13 http://archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Components [889 B]
# Get:14 http://archive.ubuntu.com/ubuntu noble-backports/main amd64 Components [7877 B]
# Get:15 http://archive.ubuntu.com/ubuntu noble-backports/universe amd64 Components [11.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble-backports/restricted amd64 Components [161 B]
# Get:17 http://archive.ubuntu.com/ubuntu noble-backports/multiverse amd64 Components [162 B]
# Hit:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Hit:19 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble InRelease
# Get:20 http://security.ubuntu.com/ubuntu noble-security/main amd64 Components [25.3 kB]
# Get:21 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Components [90.3 kB]
# Get:22 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Components [157 B]
# Get:23 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Components [158 B]
# Fetched 5332 kB in 1s (4813 kB/s)
# Reading package lists... Done
# Hit:1 https://repo.radeon.com/amdgpu/30.10/ubuntu jammy InRelease
# Hit:2 https://repo.radeon.com/rocm/apt/7.0 jammy InRelease
# Hit:3 https://repo.radeon.com/graphics/7.0/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 93 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:7.1.1-0build1~ubuntu2404).
# 0 upgraded, 0 newly installed, 0 to remove and 93 not upgraded.

# %% [markdown]
# ## Install LeRobot v0.4.1
# This cell clones the `lerobot` repository from Hugging Face, and installs the package in editable mode. Extra Features: To install additional dependencies for training SmolVLA or Pi models, refer to the [LeRobot offical page](https://huggingface.co/docs/lerobot/index).

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !cd lerobot && git checkout -b v0.4.1 v0.4.1 # let’s synchronize using this version
# !cd lerobot && pip install -e .
# Out:
# fatal: destination path 'lerobot' already exists and is not an empty directory.
# warning: refname 'v0.4.1' is ambiguous.
# fatal: a branch named 'v0.4.1' already exists
# Obtaining file:///workspace/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<4.2.0,>=4.0.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (4.1.1)
# Requirement already satisfied: diffusers<0.36.0,>=0.27.2 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (0.35.2)
# Requirement already satisfied: huggingface-hub<0.36.0,>=0.34.2 in /opt/venv/lib/python3.12/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.35.3)
# Requirement already satisfied: accelerate<2.0.0,>=1.10.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (1.12.0)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (80.9.0)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (4.1.3)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (0.8.1)
# Requirement already satisfied: opencv-python-headless<4.13.0,>=4.9.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (4.12.0.88)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (15.1.0)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (4.0.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (25.0)
# Requirement already satisfied: pynput<1.9.0,>=1.7.7 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (1.8.1)
# Requirement already satisfied: pyserial<4.0,>=3.5 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (3.5)
# Requirement already satisfied: wandb<0.22.0,>=0.20.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (0.21.4)
# Requirement already satisfied: torch<2.8.0,>=2.2.1 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (2.7.1+rocm7.0.0.lw.git698b58a9)
# Requirement already satisfied: torchcodec<0.6.0,>=0.2.1 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (0.5)
# Requirement already satisfied: torchvision<0.23.0,>=0.21.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (0.22.1+rocm7.0.0.git59a3e1f9)
# Requirement already satisfied: draccus==0.10.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (0.10.0)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (1.2.2)
# Requirement already satisfied: rerun-sdk<0.27.0,>=0.24.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (0.26.2)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (8.6.1)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /opt/venv/lib/python3.12/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1) (2.37.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.1) (3.2.0)
# Requirement already satisfied: mergedeep~=1.3 in /opt/venv/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.4.1) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /opt/venv/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.4.1) (6.0.2)
# Requirement already satisfied: pyyaml-include~=1.4 in /opt/venv/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.4.1) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /opt/venv/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.4.1) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /opt/venv/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.4.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /opt/venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (2.2.6)
# Requirement already satisfied: psutil in /opt/venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (7.1.3)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (0.7.0)
# Requirement already satisfied: filelock in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.19.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.4.0)
# Requirement already satisfied: pandas in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /opt/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.9.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /opt/venv/lib/python3.12/site-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.1) (5.5.0)
# Requirement already satisfied: importlib_metadata in /opt/venv/lib/python3.12/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (8.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/venv/lib/python3.12/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (2025.11.3)
# Requirement already satisfied: Pillow in /opt/venv/lib/python3.12/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (11.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.13.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/venv/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/venv/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/venv/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/venv/lib/python3.12/site-packages (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (1.2.0)
# Requirement already satisfied: InquirerPy==0.3.4 in /opt/venv/lib/python3.12/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /opt/venv/lib/python3.12/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /opt/venv/lib/python3.12/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /opt/venv/lib/python3.12/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (3.0.52)
# Requirement already satisfied: imageio-ffmpeg in /opt/venv/lib/python3.12/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1) (0.6.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/venv/lib/python3.12/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.1) (25.4.0)
# Requirement already satisfied: wcwidth in /opt/venv/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.2.14)
# Requirement already satisfied: six in /opt/venv/lib/python3.12/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /opt/venv/lib/python3.12/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (1.9.2)
# Requirement already satisfied: python-xlib>=0.17 in /opt/venv/lib/python3.12/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (0.33)
# Requirement already satisfied: sympy>=1.13.3 in /opt/venv/lib/python3.12/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.14.0)
# Requirement already satisfied: networkx in /opt/venv/lib/python3.12/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.5)
# Requirement already satisfied: jinja2 in /opt/venv/lib/python3.12/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.1.6)
# Requirement already satisfied: pytorch-triton-rocm==3.3.1+rocm7.0.0.git9c7bc0a3 in /opt/venv/lib/python3.12/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.3.1+rocm7.0.0.git9c7bc0a3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/venv/lib/python3.12/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.1) (1.1.0)
# Requirement already satisfied: click>=8.0.1 in /opt/venv/lib/python3.12/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/venv/lib/python3.12/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (3.1.45)
# Requirement already satisfied: platformdirs in /opt/venv/lib/python3.12/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /opt/venv/lib/python3.12/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (6.33.2)
# Requirement already satisfied: pydantic<3 in /opt/venv/lib/python3.12/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/venv/lib/python3.12/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.47.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/venv/lib/python3.12/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/venv/lib/python3.12/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/venv/lib/python3.12/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.11.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.22.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (5.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /opt/venv/lib/python3.12/site-packages (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.12/site-packages (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/venv/lib/python3.12/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.12/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/venv/lib/python3.12/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.2)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.1-0.editable-py3-none-any.whl size=15631 sha256=9170a6834c1eb1d7f6877b436c3a4e01c043e252c3abed5a955f5643b6655668
#   Stored in directory: /tmp/pip-ephem-wheel-cache-goz73oxa/wheels/05/0a/0d/80a4c08845345c44fe1e5f70929884983b90d85f46a77f7601
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.4.1
#     Uninstalling lerobot-0.4.1:
#       Successfully uninstalled lerobot-0.4.1
# Successfully installed lerobot-0.4.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Weights & Biases login
# This cell install and log into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !pip install wandb
import wandb
wandb.login(key="5480700e4b4d584d23da300912dc7e38db4d4970")
# Out:
# Requirement already satisfied: wandb in /opt/venv/lib/python3.12/site-packages (0.21.4)
# Requirement already satisfied: click>=8.0.1 in /opt/venv/lib/python3.12/site-packages (from wandb) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/venv/lib/python3.12/site-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in /opt/venv/lib/python3.12/site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /opt/venv/lib/python3.12/site-packages (from wandb) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /opt/venv/lib/python3.12/site-packages (from wandb) (6.33.2)
# Requirement already satisfied: pydantic<3 in /opt/venv/lib/python3.12/site-packages (from wandb) (2.12.5)
# Requirement already satisfied: pyyaml in /opt/venv/lib/python3.12/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/venv/lib/python3.12/site-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/venv/lib/python3.12/site-packages (from wandb) (2.47.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /opt/venv/lib/python3.12/site-packages (from wandb) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/venv/lib/python3.12/site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2025.11.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ## Login into Hugging Face Hub

# %%
from huggingface_hub import login
login(token="token_here")

# %%
# !lerobot-edit-dataset \
    --repo_id Abubakar17/mission2_take_all_from_hand_2 \
    --operation.type merge \
    --operation.repo_ids "['Abubakar17/mission_2_take', 'Abubakar17/mission_2_take_ham', 'Abubakar17/mission_2_take_box']"
# Out:
# INFO 2025-12-14 01:31:44 _dataset.py:208 Loading 3 datasets to merge
# INFO 2025-12-14 01:31:44 _dataset.py:213 Merging datasets into Abubakar17/mission2_take_all_from_hand_2
# INFO 2025-12-14 01:31:44 ggregate.py:195 Start aggregate_datasets
# Validate all meta data: 100%|██████████████████| 3/3 [00:00<00:00, 61680.94it/s]
# INFO 2025-12-14 01:31:44 ggregate.py:226 Find all tasks
# Copy data and videos: 100%|███████████████████████| 3/3 [00:03<00:00,  1.21s/it]
# INFO 2025-12-14 01:31:48 ggregate.py:515 write tasks
# INFO 2025-12-14 01:31:48 ggregate.py:518 write info
# INFO 2025-12-14 01:31:48 ggregate.py:529 write stats
# INFO 2025-12-14 01:31:48 ggregate.py:248 Aggregation complete.
# INFO 2025-12-14 01:31:48 _dataset.py:220 Merged dataset saved to /root/.cache/huggingface/lerobot/Abubakar17/mission2_take_all_from_hand_2
# INFO 2025-12-14 01:31:48 _dataset.py:221 Episodes: 60, Frames: 30290

# %%
from huggingface_hub import HfApi

hub_api = HfApi()
hub_api.create_tag("Abubakar17/mission2_take_all", tag="v3.0", repo_type="dataset")

# %% [markdown]
# ## Start Training Models with LeRobot
#
# This cell uses the lerobot-train CLI from the lerobot library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `lerobot/svla_so100_pickplace`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.The name typically includes the model type (e.g., act, smolvla), the dataset name, and additional descriptive tags.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an AMD or NVIDIA GPU.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.
#
# 7. `--policy.push_to_hub=`:
#
#    Enables automatic uploading of the trained policy to the Hugging Face Hub. You must specify `--policy.repo_id` (e.g., ${HF_USER}/{REPO_NAME}) if it is True.

# %%
# !lerobot-train \
  --dataset.repo_id=Abubakar17/mission2_take_all_from_hand_2 \
  --batch_size=16 \
  --steps=15000 \
  --output_dir=outputs/train/act_so101_mission_2_take_all_from_hand_output_2 \
  --job_name=act_so101_mission_2_take_all_from_hand_job_2 \
  --policy.repo_id=Abubakar17/take_all_from_hand_2 \
  --policy.device=cuda \
  --policy.type=act \
  --policy.push_to_hub=true \
  --wandb.enable=true  \
  --dataset.image_transforms.enable=True  \
  --save_freq=2000  \
  --eval_freq=5000
# Out:
# INFO 2025-12-14 01:32:24 ot_train.py:163 {'batch_size': 16,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': True,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'Abubakar17/mission2_take_all_from_hand_2',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 5000,
#  'job_name': 'act_so101_mission_2_take_all_from_hand_job_2',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_so101_mission_2_take_all_from_hand_output_2',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': 'Abubakar17/take_all_from_hand_2',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 2000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 15000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /opt/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /opt/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2025-12-14 01:32:25 db_utils.py:102 Logs will be synced with wandb.
# INFO 2025-12-14 01:32:25 db_utils.py:103 Track this run --> https://wandb.ai/syedabubakar03-universit-de-technologie-de-compi-gne/lerobot/runs/k9i1hbzg
# INFO 2025-12-14 01:32:25 ot_train.py:183 Creating dataset
# INFO 2025-12-14 01:32:25 ot_train.py:202 Creating policy
# INFO 2025-12-14 01:32:26 ot_train.py:247 Creating optimizer and scheduler
# INFO 2025-12-14 01:32:26 ot_train.py:259 Output dir: outputs/train/act_so101_mission_2_take_all_from_hand_output_2
# INFO 2025-12-14 01:32:26 ot_train.py:262 cfg.steps=15000 (15K)
# INFO 2025-12-14 01:32:26 ot_train.py:263 dataset.num_frames=30290 (30K)
# INFO 2025-12-14 01:32:26 ot_train.py:264 dataset.num_episodes=60
# INFO 2025-12-14 01:32:26 ot_train.py:267 Effective batch size: 16 x 1 = 16
# INFO 2025-12-14 01:32:26 ot_train.py:268 num_learnable_params=51597190 (52M)
# INFO 2025-12-14 01:32:26 ot_train.py:269 num_total_params=51597190 (52M)
# INFO 2025-12-14 01:32:26 ot_train.py:324 Start offline training on a fixed dataset
# INFO 2025-12-14 01:33:19 ot_train.py:351 step:200 smpl:3K ep:6 epch:0.11 loss:6.252 grdn:118.451 lr:1.0e-05 updt_s:0.174 data_s:0.092
# INFO 2025-12-14 01:33:51 ot_train.py:351 step:400 smpl:6K ep:13 epch:0.21 loss:2.620 grdn:61.470 lr:1.0e-05 updt_s:0.072 data_s:0.087
# INFO 2025-12-14 01:34:23 ot_train.py:351 step:600 smpl:10K ep:19 epch:0.32 loss:2.181 grdn:54.680 lr:1.0e-05 updt_s:0.073 data_s:0.088
# INFO 2025-12-14 01:34:55 ot_train.py:351 step:800 smpl:13K ep:25 epch:0.42 loss:1.883 grdn:50.454 lr:1.0e-05 updt_s:0.072 data_s:0.087
# INFO 2025-12-14 01:35:28 ot_train.py:351 step:1K smpl:16K ep:32 epch:0.53 loss:1.642 grdn:47.455 lr:1.0e-05 updt_s:0.072 data_s:0.089
# INFO 2025-12-14 01:36:00 ot_train.py:351 step:1K smpl:19K ep:38 epch:0.63 loss:1.446 grdn:44.804 lr:1.0e-05 updt_s:0.072 data_s:0.088
# INFO 2025-12-14 01:36:32 ot_train.py:351 step:1K smpl:22K ep:44 epch:0.74 loss:1.261 grdn:40.984 lr:1.0e-05 updt_s:0.072 data_s:0.091
# INFO 2025-12-14 01:37:06 ot_train.py:351 step:2K smpl:26K ep:51 epch:0.85 loss:1.110 grdn:38.491 lr:1.0e-05 updt_s:0.072 data_s:0.093
# INFO 2025-12-14 01:37:38 ot_train.py:351 step:2K smpl:29K ep:57 epch:0.95 loss:0.987 grdn:37.066 lr:1.0e-05 updt_s:0.073 data_s:0.089
# INFO 2025-12-14 01:38:14 ot_train.py:351 step:2K smpl:32K ep:63 epch:1.06 loss:0.869 grdn:34.894 lr:1.0e-05 updt_s:0.084 data_s:0.098
# INFO 2025-12-14 01:38:14 ot_train.py:361 Checkpoint policy after step 2000
# INFO 2025-12-14 01:38:49 ot_train.py:351 step:2K smpl:35K ep:70 epch:1.16 loss:0.772 grdn:32.524 lr:1.0e-05 updt_s:0.073 data_s:0.093
# INFO 2025-12-14 01:39:24 ot_train.py:351 step:2K smpl:38K ep:76 epch:1.27 loss:0.678 grdn:29.711 lr:1.0e-05 updt_s:0.072 data_s:0.099
# INFO 2025-12-14 01:39:57 ot_train.py:351 step:3K smpl:42K ep:82 epch:1.37 loss:0.603 grdn:28.385 lr:1.0e-05 updt_s:0.072 data_s:0.096
# INFO 2025-12-14 01:40:31 ot_train.py:351 step:3K smpl:45K ep:89 epch:1.48 loss:0.544 grdn:26.993 lr:1.0e-05 updt_s:0.073 data_s:0.097
# INFO 2025-12-14 01:41:05 ot_train.py:351 step:3K smpl:48K ep:95 epch:1.58 loss:0.491 grdn:25.451 lr:1.0e-05 updt_s:0.073 data_s:0.094
# INFO 2025-12-14 01:41:39 ot_train.py:351 step:3K smpl:51K ep:101 epch:1.69 loss:0.444 grdn:24.563 lr:1.0e-05 updt_s:0.074 data_s:0.097
# INFO 2025-12-14 01:42:13 ot_train.py:351 step:3K smpl:54K ep:108 epch:1.80 loss:0.406 grdn:23.499 lr:1.0e-05 updt_s:0.072 data_s:0.097
# INFO 2025-12-14 01:42:47 ot_train.py:351 step:4K smpl:58K ep:114 epch:1.90 loss:0.374 grdn:21.905 lr:1.0e-05 updt_s:0.073 data_s:0.096
# INFO 2025-12-14 01:43:22 ot_train.py:351 step:4K smpl:61K ep:120 epch:2.01 loss:0.349 grdn:21.306 lr:1.0e-05 updt_s:0.073 data_s:0.105
# INFO 2025-12-14 01:43:56 ot_train.py:351 step:4K smpl:64K ep:127 epch:2.11 loss:0.322 grdn:20.477 lr:1.0e-05 updt_s:0.073 data_s:0.094
# INFO 2025-12-14 01:43:56 ot_train.py:361 Checkpoint policy after step 4000
# INFO 2025-12-14 01:44:28 ot_train.py:351 step:4K smpl:67K ep:133 epch:2.22 loss:0.307 grdn:19.770 lr:1.0e-05 updt_s:0.073 data_s:0.081
# INFO 2025-12-14 01:44:59 ot_train.py:351 step:4K smpl:70K ep:139 epch:2.32 loss:0.291 grdn:18.937 lr:1.0e-05 updt_s:0.074 data_s:0.081
# INFO 2025-12-14 01:45:30 ot_train.py:351 step:5K smpl:74K ep:146 epch:2.43 loss:0.276 grdn:17.914 lr:1.0e-05 updt_s:0.073 data_s:0.083
# INFO 2025-12-14 01:46:01 ot_train.py:351 step:5K smpl:77K ep:152 epch:2.54 loss:0.264 grdn:17.986 lr:1.0e-05 updt_s:0.072 data_s:0.083
# INFO 2025-12-14 01:46:33 ot_train.py:351 step:5K smpl:80K ep:158 epch:2.64 loss:0.251 grdn:17.019 lr:1.0e-05 updt_s:0.073 data_s:0.084
# INFO 2025-12-14 01:47:04 ot_train.py:351 step:5K smpl:83K ep:165 epch:2.75 loss:0.242 grdn:16.822 lr:1.0e-05 updt_s:0.073 data_s:0.084
# INFO 2025-12-14 01:47:36 ot_train.py:351 step:5K smpl:86K ep:171 epch:2.85 loss:0.236 grdn:16.092 lr:1.0e-05 updt_s:0.073 data_s:0.086
# INFO 2025-12-14 01:48:07 ot_train.py:351 step:6K smpl:90K ep:177 epch:2.96 loss:0.226 grdn:15.903 lr:1.0e-05 updt_s:0.073 data_s:0.081
# INFO 2025-12-14 01:48:41 ot_train.py:351 step:6K smpl:93K ep:184 epch:3.06 loss:0.220 grdn:15.701 lr:1.0e-05 updt_s:0.074 data_s:0.098
# INFO 2025-12-14 01:49:13 ot_train.py:351 step:6K smpl:96K ep:190 epch:3.17 loss:0.212 grdn:15.123 lr:1.0e-05 updt_s:0.073 data_s:0.087
# INFO 2025-12-14 01:49:13 ot_train.py:361 Checkpoint policy after step 6000
# INFO 2025-12-14 01:49:46 ot_train.py:351 step:6K smpl:99K ep:197 epch:3.28 loss:0.207 grdn:15.730 lr:1.0e-05 updt_s:0.073 data_s:0.084
# INFO 2025-12-14 01:50:19 ot_train.py:351 step:6K smpl:102K ep:203 epch:3.38 loss:0.202 grdn:15.046 lr:1.0e-05 updt_s:0.073 data_s:0.089
# INFO 2025-12-14 01:50:50 ot_train.py:351 step:7K smpl:106K ep:209 epch:3.49 loss:0.199 grdn:14.232 lr:1.0e-05 updt_s:0.073 data_s:0.085
# INFO 2025-12-14 01:51:23 ot_train.py:351 step:7K smpl:109K ep:216 epch:3.59 loss:0.193 grdn:14.608 lr:1.0e-05 updt_s:0.073 data_s:0.091
# INFO 2025-12-14 01:51:55 ot_train.py:351 step:7K smpl:112K ep:222 epch:3.70 loss:0.191 grdn:14.141 lr:1.0e-05 updt_s:0.073 data_s:0.086
# INFO 2025-12-14 01:52:27 ot_train.py:351 step:7K smpl:115K ep:228 epch:3.80 loss:0.187 grdn:14.389 lr:1.0e-05 updt_s:0.073 data_s:0.088
# INFO 2025-12-14 01:53:00 ot_train.py:351 step:7K smpl:118K ep:235 epch:3.91 loss:0.182 grdn:13.666 lr:1.0e-05 updt_s:0.073 data_s:0.091
# INFO 2025-12-14 01:53:35 ot_train.py:351 step:8K smpl:122K ep:241 epch:4.01 loss:0.178 grdn:13.927 lr:1.0e-05 updt_s:0.073 data_s:0.099
# INFO 2025-12-14 01:54:07 ot_train.py:351 step:8K smpl:125K ep:247 epch:4.12 loss:0.174 grdn:13.676 lr:1.0e-05 updt_s:0.073 data_s:0.089
# INFO 2025-12-14 01:54:40 ot_train.py:351 step:8K smpl:128K ep:254 epch:4.23 loss:0.172 grdn:13.421 lr:1.0e-05 updt_s:0.073 data_s:0.091
# INFO 2025-12-14 01:54:40 ot_train.py:361 Checkpoint policy after step 8000
# INFO 2025-12-14 01:55:14 ot_train.py:351 step:8K smpl:131K ep:260 epch:4.33 loss:0.168 grdn:13.074 lr:1.0e-05 updt_s:0.073 data_s:0.089
# INFO 2025-12-14 01:55:46 ot_train.py:351 step:8K smpl:134K ep:266 epch:4.44 loss:0.166 grdn:12.471 lr:1.0e-05 updt_s:0.074 data_s:0.088
# INFO 2025-12-14 01:56:19 ot_train.py:351 step:9K smpl:138K ep:273 epch:4.54 loss:0.162 grdn:12.426 lr:1.0e-05 updt_s:0.073 data_s:0.090
# INFO 2025-12-14 01:56:51 ot_train.py:351 step:9K smpl:141K ep:279 epch:4.65 loss:0.160 grdn:12.003 lr:1.0e-05 updt_s:0.073 data_s:0.089
# INFO 2025-12-14 01:57:24 ot_train.py:351 step:9K smpl:144K ep:285 epch:4.75 loss:0.159 grdn:12.670 lr:1.0e-05 updt_s:0.073 data_s:0.089
# INFO 2025-12-14 01:57:56 ot_train.py:351 step:9K smpl:147K ep:292 epch:4.86 loss:0.156 grdn:12.177 lr:1.0e-05 updt_s:0.073 data_s:0.087
# INFO 2025-12-14 01:58:28 ot_train.py:351 step:9K smpl:150K ep:298 epch:4.97 loss:0.154 grdn:12.352 lr:1.0e-05 updt_s:0.073 data_s:0.089
# INFO 2025-12-14 01:59:01 ot_train.py:351 step:10K smpl:154K ep:304 epch:5.07 loss:0.151 grdn:12.097 lr:1.0e-05 updt_s:0.073 data_s:0.092
# INFO 2025-12-14 01:59:32 ot_train.py:351 step:10K smpl:157K ep:311 epch:5.18 loss:0.148 grdn:11.713 lr:1.0e-05 updt_s:0.073 data_s:0.082
# INFO 2025-12-14 02:00:04 ot_train.py:351 step:10K smpl:160K ep:317 epch:5.28 loss:0.146 grdn:11.288 lr:1.0e-05 updt_s:0.073 data_s:0.084
# INFO 2025-12-14 02:00:04 ot_train.py:361 Checkpoint policy after step 10000
# INFO 2025-12-14 02:00:35 ot_train.py:351 step:10K smpl:163K ep:323 epch:5.39 loss:0.145 grdn:11.477 lr:1.0e-05 updt_s:0.073 data_s:0.078
# INFO 2025-12-14 02:01:06 ot_train.py:351 step:10K smpl:166K ep:330 epch:5.49 loss:0.143 grdn:11.504 lr:1.0e-05 updt_s:0.073 data_s:0.081
# INFO 2025-12-14 02:01:37 ot_train.py:351 step:11K smpl:170K ep:336 epch:5.60 loss:0.141 grdn:11.141 lr:1.0e-05 updt_s:0.073 data_s:0.081
# INFO 2025-12-14 02:02:08 ot_train.py:351 step:11K smpl:173K ep:342 epch:5.70 loss:0.139 grdn:10.608 lr:1.0e-05 updt_s:0.073 data_s:0.083
# INFO 2025-12-14 02:02:39 ot_train.py:351 step:11K smpl:176K ep:349 epch:5.81 loss:0.137 grdn:10.739 lr:1.0e-05 updt_s:0.073 data_s:0.080
# INFO 2025-12-14 02:03:09 ot_train.py:351 step:11K smpl:179K ep:355 epch:5.92 loss:0.137 grdn:10.742 lr:1.0e-05 updt_s:0.072 data_s:0.080
# INFO 2025-12-14 02:03:42 ot_train.py:351 step:11K smpl:182K ep:361 epch:6.02 loss:0.136 grdn:10.922 lr:1.0e-05 updt_s:0.073 data_s:0.089
# INFO 2025-12-14 02:04:14 ot_train.py:351 step:12K smpl:186K ep:368 epch:6.13 loss:0.132 grdn:10.503 lr:1.0e-05 updt_s:0.073 data_s:0.088
# INFO 2025-12-14 02:04:46 ot_train.py:351 step:12K smpl:189K ep:374 epch:6.23 loss:0.129 grdn:10.234 lr:1.0e-05 updt_s:0.073 data_s:0.085
# INFO 2025-12-14 02:05:18 ot_train.py:351 step:12K smpl:192K ep:380 epch:6.34 loss:0.128 grdn:10.478 lr:1.0e-05 updt_s:0.073 data_s:0.087
# INFO 2025-12-14 02:05:18 ot_train.py:361 Checkpoint policy after step 12000
# INFO 2025-12-14 02:05:51 ot_train.py:351 step:12K smpl:195K ep:387 epch:6.44 loss:0.128 grdn:9.710 lr:1.0e-05 updt_s:0.073 data_s:0.084
# INFO 2025-12-14 02:06:22 ot_train.py:351 step:12K smpl:198K ep:393 epch:6.55 loss:0.128 grdn:10.251 lr:1.0e-05 updt_s:0.074 data_s:0.083
# INFO 2025-12-14 02:06:53 ot_train.py:351 step:13K smpl:202K ep:399 epch:6.66 loss:0.124 grdn:9.736 lr:1.0e-05 updt_s:0.073 data_s:0.081
# INFO 2025-12-14 02:07:23 ot_train.py:351 step:13K smpl:205K ep:406 epch:6.76 loss:0.123 grdn:9.652 lr:1.0e-05 updt_s:0.073 data_s:0.079
# INFO 2025-12-14 02:07:54 ot_train.py:351 step:13K smpl:208K ep:412 epch:6.87 loss:0.123 grdn:10.052 lr:1.0e-05 updt_s:0.073 data_s:0.080
# INFO 2025-12-14 02:08:24 ot_train.py:351 step:13K smpl:211K ep:418 epch:6.97 loss:0.123 grdn:9.638 lr:1.0e-05 updt_s:0.073 data_s:0.079
# INFO 2025-12-14 02:08:57 ot_train.py:351 step:13K smpl:214K ep:425 epch:7.08 loss:0.120 grdn:10.170 lr:1.0e-05 updt_s:0.072 data_s:0.091
# INFO 2025-12-14 02:09:27 ot_train.py:351 step:14K smpl:218K ep:431 epch:7.18 loss:0.118 grdn:9.935 lr:1.0e-05 updt_s:0.074 data_s:0.075
# INFO 2025-12-14 02:09:57 ot_train.py:351 step:14K smpl:221K ep:437 epch:7.29 loss:0.117 grdn:9.213 lr:1.0e-05 updt_s:0.073 data_s:0.077
# INFO 2025-12-14 02:10:27 ot_train.py:351 step:14K smpl:224K ep:444 epch:7.40 loss:0.116 grdn:9.015 lr:1.0e-05 updt_s:0.073 data_s:0.076
# INFO 2025-12-14 02:10:27 ot_train.py:361 Checkpoint policy after step 14000
# INFO 2025-12-14 02:10:58 ot_train.py:351 step:14K smpl:227K ep:450 epch:7.50 loss:0.116 grdn:9.305 lr:1.0e-05 updt_s:0.073 data_s:0.074
# INFO 2025-12-14 02:11:27 ot_train.py:351 step:14K smpl:230K ep:456 epch:7.61 loss:0.115 grdn:9.631 lr:1.0e-05 updt_s:0.073 data_s:0.076
# INFO 2025-12-14 02:11:58 ot_train.py:351 step:15K smpl:234K ep:463 epch:7.71 loss:0.113 grdn:8.934 lr:1.0e-05 updt_s:0.073 data_s:0.077
# INFO 2025-12-14 02:12:28 ot_train.py:351 step:15K smpl:237K ep:469 epch:7.82 loss:0.112 grdn:9.286 lr:1.0e-05 updt_s:0.073 data_s:0.080
# INFO 2025-12-14 02:12:58 ot_train.py:351 step:15K smpl:240K ep:475 epch:7.92 loss:0.113 grdn:9.086 lr:1.0e-05 updt_s:0.074 data_s:0.074
# INFO 2025-12-14 02:12:58 ot_train.py:361 Checkpoint policy after step 15000
# INFO 2025-12-14 02:12:59 ot_train.py:430 End of training
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ..._hand_2/model.safetensors:   0%|              |  782kB /  207MB
#
# Processing Files (0 / 1)      :   0%|              |  782kB /  207MB, 3.90MB/s
#
# Processing Files (0 / 1)      :   1%|▏             | 1.91MB /  207MB, 4.77MB/s
# New Data Upload               :   2%|▏             | 1.13MB / 67.1MB, 2.81MB/s
#
# Processing Files (0 / 1)      :  16%|██▎           | 34.0MB /  207MB, 56.7MB/s
# New Data Upload               :  25%|███▍          | 33.2MB /  134MB, 55.4MB/s
#
# Processing Files (0 / 1)      :  33%|████▋         | 68.9MB /  207MB, 86.2MB/s
# New Data Upload               :  33%|████▋         | 68.1MB /  206MB, 85.2MB/s
#
# Processing Files (0 / 1)      :  52%|███████▎      |  108MB /  207MB,  108MB/s
# New Data Upload               :  52%|███████▎      |  107MB /  206MB,  107MB/s
#
# Processing Files (0 / 1)      :  83%|███████████▌  |  171MB /  207MB,  142MB/s
# New Data Upload               :  83%|███████████▌  |  170MB /  206MB,  142MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉|  206MB /  207MB,  147MB/s
# New Data Upload               : 100%|█████████████▉|  206MB /  206MB,  147MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉|  206MB /  207MB,  129MB/s
# New Data Upload               : 100%|█████████████▉|  206MB /  206MB,  129MB/s
#
#   ..._hand_2/model.safetensors: 100%|█████████████▉|  206MB /  207MB
#
# Processing Files (0 / 1)      : 100%|█████████████▉|  207MB /  207MB,  103MB/s
# New Data Upload               : 100%|█████████████▉|  206MB /  206MB,  103MB/s
#
# Processing Files (1 / 1)      : 100%|██████████████|  207MB /  207MB, 94.0MB/s
# New Data Upload               : 100%|██████████████|  206MB /  206MB, 93.6MB/s
#
#   ..._hand_2/model.safetensors: 100%|██████████████|  207MB /  207MB
#
# Processing Files (1 / 1)      : 100%|██████████████|  207MB /  207MB, 86.1MB/s
# New Data Upload               : 100%|██████████████|  206MB /  206MB, 85.8MB/s
#   ..._hand_2/model.safetensors: 100%|██████████████|  207MB /  207MB
# INFO 2025-12-14 02:13:04 etrained.py:237 Model pushed to https://huggingface.co/Abubakar17/take_all_from_hand_2
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.52kB / 7.52kB,   ???B/s
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.52kB / 7.52kB,  0.00B/s
# New Data Upload               : |                  |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.52kB / 7.52kB,   ???B/s
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.52kB / 7.52kB,  0.00B/s
# New Data Upload               : |                  |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB

# %%
# !huggingface-cli repo create Abubakar17/so101-mission_2_drop_ham --type model
# Out:
# The --type argument is deprecated and will be removed in a future version. Use --repo-type instead.
# ⚠️  Warning: 'huggingface-cli repo' is deprecated. Use 'hf repo' instead.
# Successfully created Abubakar17/so101-mission_2_drop_ham on the Hub.
# Your repo is now available at https://huggingface.co/Abubakar17/so101-mission_2_drop_ham

# %%
from huggingface_hub import HfApi
api = HfApi()
api.upload_folder(
    folder_path="outputs/train/act_so101_mission_2_drop_ham_output/checkpoints/015000/pretrained_model",
    repo_id="Abubakar17/so101-mission_2_drop_ham",
    repo_type="model",
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/Abubakar17/so101-mission_2_drop_ham/commit/c38c51659966f9dd9b1f24d0a22b9e2222dc9037', commit_message='Upload folder using huggingface_hub', commit_description='', oid='c38c51659966f9dd9b1f24d0a22b9e2222dc9037', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Abubakar17/so101-mission_2_drop_ham', endpoint='https://huggingface.co', repo_type='model', repo_id='Abubakar17/so101-mission_2_drop_ham'), pr_revision=None, pr_num=None)

# %% [raw]
# **Notes**:
#
# - If using a local dataset, add `--dataset.root=/path/to/dataset`.
# - Adjust `--batch_size` and `--steps` based on your hardware and dataset.
# - Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`
# - Training progress visualized in your wandb dashboard

# %% [markdown]
# X-VLA

# %%
# !lerobot-edit-dataset \
    --repo_id Abubakar17/mission2_drop_all_xvla \
    --operation.type merge \
    --operation.repo_ids "['Abubakar17/mission_2_drop_box', 'Abubakar17/mission_2_drop_ham', 'Abubakar17/mission_2_drop_tape']"
# Out:
# INFO 2025-12-13 18:52:38 _dataset.py:208 Loading 3 datasets to merge
# INFO 2025-12-13 18:52:38 _dataset.py:213 Merging datasets into Abubakar17/mission2_drop_all_xvla
# INFO 2025-12-13 18:52:38 ggregate.py:195 Start aggregate_datasets
# Validate all meta data: 100%|█████████████████| 3/3 [00:00<00:00, 104857.60it/s]
# INFO 2025-12-13 18:52:38 ggregate.py:226 Find all tasks
# Copy data and videos: 100%|███████████████████████| 3/3 [00:13<00:00,  4.53s/it]
# INFO 2025-12-13 18:52:52 ggregate.py:515 write tasks
# INFO 2025-12-13 18:52:52 ggregate.py:518 write info
# INFO 2025-12-13 18:52:52 ggregate.py:529 write stats
# INFO 2025-12-13 18:52:52 ggregate.py:248 Aggregation complete.
# INFO 2025-12-13 18:52:52 _dataset.py:220 Merged dataset saved to /root/.cache/huggingface/lerobot/Abubakar17/mission2_drop_all_xvla
# INFO 2025-12-13 18:52:52 _dataset.py:221 Episodes: 120, Frames: 79781

# %%
# !lerobot-train \
  --dataset.repo_id=Abubakar17/mission2_drop_all_xvla \
  --batch_size=16 \
  --steps=15000 \
  --output_dir=outputs/train/act_so101_mission_2_drop_all_output \
  --job_name=act_so101_mission_2_drop_all_job \
  --policy.repo_id=Abubakar17/drop_all_hand \
  --policy.device=cuda \
  --policy.type=act \
  --policy.push_to_hub=true \
  --wandb.enable=true  \
  --dataset.image_transforms.enable=True  \
  --save_freq=2000  \
  --eval_freq=5000
# Out:
# INFO 2025-12-13 19:48:27 ot_train.py:163 {'batch_size': 16,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': True,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'Abubakar17/mission2_drop_all_xvla',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 5000,
#  'job_name': 'act_so101_mission_2_drop_all_job',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_so101_mission_2_drop_all_output',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': 'Abubakar17/drop_all_hand',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 2000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 15000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /opt/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /opt/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2025-12-13 19:48:28 db_utils.py:102 Logs will be synced with wandb.
# INFO 2025-12-13 19:48:28 db_utils.py:103 Track this run --> https://wandb.ai/syedabubakar03-universit-de-technologie-de-compi-gne/lerobot/runs/pcz1tuwx
# INFO 2025-12-13 19:48:28 ot_train.py:183 Creating dataset
# INFO 2025-12-13 19:48:28 ot_train.py:202 Creating policy
# INFO 2025-12-13 19:48:29 ot_train.py:247 Creating optimizer and scheduler
# INFO 2025-12-13 19:48:29 ot_train.py:259 Output dir: outputs/train/act_so101_mission_2_drop_all_output
# INFO 2025-12-13 19:48:29 ot_train.py:262 cfg.steps=15000 (15K)
# INFO 2025-12-13 19:48:29 ot_train.py:263 dataset.num_frames=79781 (80K)
# INFO 2025-12-13 19:48:29 ot_train.py:264 dataset.num_episodes=120
# INFO 2025-12-13 19:48:29 ot_train.py:267 Effective batch size: 16 x 1 = 16
# INFO 2025-12-13 19:48:29 ot_train.py:268 num_learnable_params=51597190 (52M)
# INFO 2025-12-13 19:48:29 ot_train.py:269 num_total_params=51597190 (52M)
# INFO 2025-12-13 19:48:29 ot_train.py:324 Start offline training on a fixed dataset
# INFO 2025-12-13 19:49:26 ot_train.py:351 step:200 smpl:3K ep:5 epch:0.04 loss:6.359 grdn:121.635 lr:1.0e-05 updt_s:0.179 data_s:0.104
# INFO 2025-12-13 19:50:01 ot_train.py:351 step:400 smpl:6K ep:10 epch:0.08 loss:2.664 grdn:62.717 lr:1.0e-05 updt_s:0.074 data_s:0.104
# INFO 2025-12-13 19:50:37 ot_train.py:351 step:600 smpl:10K ep:14 epch:0.12 loss:2.223 grdn:55.035 lr:1.0e-05 updt_s:0.075 data_s:0.103
# INFO 2025-12-13 19:51:13 ot_train.py:351 step:800 smpl:13K ep:19 epch:0.16 loss:1.932 grdn:50.796 lr:1.0e-05 updt_s:0.074 data_s:0.103
# INFO 2025-12-13 19:51:47 ot_train.py:351 step:1K smpl:16K ep:24 epch:0.20 loss:1.678 grdn:47.392 lr:1.0e-05 updt_s:0.074 data_s:0.099
# INFO 2025-12-13 19:52:22 ot_train.py:351 step:1K smpl:19K ep:29 epch:0.24 loss:1.480 grdn:45.102 lr:1.0e-05 updt_s:0.074 data_s:0.097
# INFO 2025-12-13 19:52:57 ot_train.py:351 step:1K smpl:22K ep:34 epch:0.28 loss:1.301 grdn:41.662 lr:1.0e-05 updt_s:0.074 data_s:0.104
# INFO 2025-12-13 19:53:34 ot_train.py:351 step:2K smpl:26K ep:39 epch:0.32 loss:1.138 grdn:38.351 lr:1.0e-05 updt_s:0.074 data_s:0.106
# INFO 2025-12-13 19:54:09 ot_train.py:351 step:2K smpl:29K ep:43 epch:0.36 loss:1.013 grdn:36.877 lr:1.0e-05 updt_s:0.076 data_s:0.102
# INFO 2025-12-13 19:54:44 ot_train.py:351 step:2K smpl:32K ep:48 epch:0.40 loss:0.889 grdn:34.068 lr:1.0e-05 updt_s:0.075 data_s:0.100
# INFO 2025-12-13 19:54:44 ot_train.py:361 Checkpoint policy after step 2000
# INFO 2025-12-13 19:55:20 ot_train.py:351 step:2K smpl:35K ep:53 epch:0.44 loss:0.790 grdn:32.158 lr:1.0e-05 updt_s:0.075 data_s:0.097
# INFO 2025-12-13 19:55:55 ot_train.py:351 step:2K smpl:38K ep:58 epch:0.48 loss:0.698 grdn:29.750 lr:1.0e-05 updt_s:0.075 data_s:0.098
# INFO 2025-12-13 19:56:31 ot_train.py:351 step:3K smpl:42K ep:63 epch:0.52 loss:0.627 grdn:28.557 lr:1.0e-05 updt_s:0.075 data_s:0.105
# INFO 2025-12-13 19:57:06 ot_train.py:351 step:3K smpl:45K ep:67 epch:0.56 loss:0.558 grdn:26.805 lr:1.0e-05 updt_s:0.074 data_s:0.103
# INFO 2025-12-13 19:57:41 ot_train.py:351 step:3K smpl:48K ep:72 epch:0.60 loss:0.509 grdn:25.330 lr:1.0e-05 updt_s:0.076 data_s:0.098
# INFO 2025-12-13 19:58:17 ot_train.py:351 step:3K smpl:51K ep:77 epch:0.64 loss:0.464 grdn:23.751 lr:1.0e-05 updt_s:0.074 data_s:0.102
# INFO 2025-12-13 19:58:52 ot_train.py:351 step:3K smpl:54K ep:82 epch:0.68 loss:0.429 grdn:22.714 lr:1.0e-05 updt_s:0.075 data_s:0.102
# INFO 2025-12-13 19:59:28 ot_train.py:351 step:4K smpl:58K ep:87 epch:0.72 loss:0.394 grdn:21.476 lr:1.0e-05 updt_s:0.074 data_s:0.102
# INFO 2025-12-13 20:00:03 ot_train.py:351 step:4K smpl:61K ep:91 epch:0.76 loss:0.369 grdn:21.139 lr:1.0e-05 updt_s:0.075 data_s:0.104
# INFO 2025-12-13 20:00:40 ot_train.py:351 step:4K smpl:64K ep:96 epch:0.80 loss:0.343 grdn:19.703 lr:1.0e-05 updt_s:0.075 data_s:0.108
# INFO 2025-12-13 20:00:40 ot_train.py:361 Checkpoint policy after step 4000
# INFO 2025-12-13 20:01:18 ot_train.py:351 step:4K smpl:67K ep:101 epch:0.84 loss:0.330 grdn:19.553 lr:1.0e-05 updt_s:0.076 data_s:0.106
# INFO 2025-12-13 20:01:56 ot_train.py:351 step:4K smpl:70K ep:106 epch:0.88 loss:0.309 grdn:18.067 lr:1.0e-05 updt_s:0.074 data_s:0.115
# INFO 2025-12-13 20:02:34 ot_train.py:351 step:5K smpl:74K ep:111 epch:0.92 loss:0.297 grdn:18.121 lr:1.0e-05 updt_s:0.075 data_s:0.114
# INFO 2025-12-13 20:03:11 ot_train.py:351 step:5K smpl:77K ep:116 epch:0.96 loss:0.285 grdn:17.001 lr:1.0e-05 updt_s:0.074 data_s:0.112
# INFO 2025-12-13 20:05:56 ot_train.py:351 step:5K smpl:80K ep:120 epch:1.00 loss:0.280 grdn:16.916 lr:1.0e-05 updt_s:0.707 data_s:0.116
# INFO 2025-12-13 20:06:34 ot_train.py:351 step:5K smpl:83K ep:125 epch:1.04 loss:0.267 grdn:16.649 lr:1.0e-05 updt_s:0.075 data_s:0.113
# INFO 2025-12-13 20:07:11 ot_train.py:351 step:5K smpl:86K ep:130 epch:1.08 loss:0.254 grdn:15.767 lr:1.0e-05 updt_s:0.075 data_s:0.109
# INFO 2025-12-13 20:07:47 ot_train.py:351 step:6K smpl:90K ep:135 epch:1.12 loss:0.248 grdn:15.496 lr:1.0e-05 updt_s:0.077 data_s:0.105
# INFO 2025-12-13 20:08:23 ot_train.py:351 step:6K smpl:93K ep:140 epch:1.16 loss:0.244 grdn:15.748 lr:1.0e-05 updt_s:0.075 data_s:0.104
# INFO 2025-12-13 20:08:58 ot_train.py:351 step:6K smpl:96K ep:144 epch:1.20 loss:0.237 grdn:14.995 lr:1.0e-05 updt_s:0.075 data_s:0.101
# INFO 2025-12-13 20:08:58 ot_train.py:361 Checkpoint policy after step 6000
# INFO 2025-12-13 20:09:34 ot_train.py:351 step:6K smpl:99K ep:149 epch:1.24 loss:0.231 grdn:14.642 lr:1.0e-05 updt_s:0.075 data_s:0.098
# INFO 2025-12-13 20:10:10 ot_train.py:351 step:6K smpl:102K ep:154 epch:1.28 loss:0.225 grdn:14.248 lr:1.0e-05 updt_s:0.075 data_s:0.105
# INFO 2025-12-13 20:10:46 ot_train.py:351 step:7K smpl:106K ep:159 epch:1.32 loss:0.219 grdn:13.964 lr:1.0e-05 updt_s:0.075 data_s:0.104
# INFO 2025-12-13 20:11:22 ot_train.py:351 step:7K smpl:109K ep:164 epch:1.36 loss:0.217 grdn:14.042 lr:1.0e-05 updt_s:0.075 data_s:0.104
# INFO 2025-12-13 20:11:58 ot_train.py:351 step:7K smpl:112K ep:168 epch:1.40 loss:0.214 grdn:13.990 lr:1.0e-05 updt_s:0.076 data_s:0.101
# INFO 2025-12-13 20:12:32 ot_train.py:351 step:7K smpl:115K ep:173 epch:1.44 loss:0.209 grdn:13.376 lr:1.0e-05 updt_s:0.075 data_s:0.098
# INFO 2025-12-13 20:13:07 ot_train.py:351 step:7K smpl:118K ep:178 epch:1.48 loss:0.202 grdn:13.036 lr:1.0e-05 updt_s:0.075 data_s:0.096
# INFO 2025-12-13 20:13:41 ot_train.py:351 step:8K smpl:122K ep:183 epch:1.52 loss:0.199 grdn:13.061 lr:1.0e-05 updt_s:0.075 data_s:0.097
# INFO 2025-12-13 20:14:18 ot_train.py:351 step:8K smpl:125K ep:188 epch:1.56 loss:0.194 grdn:12.287 lr:1.0e-05 updt_s:0.075 data_s:0.107
# INFO 2025-12-13 20:14:53 ot_train.py:351 step:8K smpl:128K ep:193 epch:1.60 loss:0.193 grdn:12.709 lr:1.0e-05 updt_s:0.076 data_s:0.100
# INFO 2025-12-13 20:14:53 ot_train.py:361 Checkpoint policy after step 8000
# INFO 2025-12-13 20:15:30 ot_train.py:351 step:8K smpl:131K ep:197 epch:1.64 loss:0.193 grdn:12.590 lr:1.0e-05 updt_s:0.076 data_s:0.100
# INFO 2025-12-13 20:16:06 ot_train.py:351 step:8K smpl:134K ep:202 epch:1.68 loss:0.188 grdn:12.100 lr:1.0e-05 updt_s:0.075 data_s:0.107
# INFO 2025-12-13 20:16:42 ot_train.py:351 step:9K smpl:138K ep:207 epch:1.72 loss:0.188 grdn:12.296 lr:1.0e-05 updt_s:0.075 data_s:0.103
# INFO 2025-12-13 20:17:18 ot_train.py:351 step:9K smpl:141K ep:212 epch:1.76 loss:0.183 grdn:12.004 lr:1.0e-05 updt_s:0.075 data_s:0.105
# INFO 2025-12-13 20:17:54 ot_train.py:351 step:9K smpl:144K ep:217 epch:1.80 loss:0.180 grdn:11.604 lr:1.0e-05 updt_s:0.075 data_s:0.105
# INFO 2025-12-13 20:18:30 ot_train.py:351 step:9K smpl:147K ep:221 epch:1.85 loss:0.179 grdn:11.672 lr:1.0e-05 updt_s:0.075 data_s:0.103
# INFO 2025-12-13 20:19:05 ot_train.py:351 step:9K smpl:150K ep:226 epch:1.89 loss:0.175 grdn:11.605 lr:1.0e-05 updt_s:0.077 data_s:0.102
# INFO 2025-12-13 20:19:42 ot_train.py:351 step:10K smpl:154K ep:231 epch:1.93 loss:0.176 grdn:11.405 lr:1.0e-05 updt_s:0.076 data_s:0.103
# INFO 2025-12-13 20:20:17 ot_train.py:351 step:10K smpl:157K ep:236 epch:1.97 loss:0.174 grdn:10.991 lr:1.0e-05 updt_s:0.075 data_s:0.103
# INFO 2025-12-13 20:20:56 ot_train.py:351 step:10K smpl:160K ep:241 epch:2.01 loss:0.171 grdn:10.921 lr:1.0e-05 updt_s:0.076 data_s:0.115
# INFO 2025-12-13 20:20:56 ot_train.py:361 Checkpoint policy after step 10000
# INFO 2025-12-13 20:21:32 ot_train.py:351 step:10K smpl:163K ep:245 epch:2.05 loss:0.168 grdn:10.886 lr:1.0e-05 updt_s:0.075 data_s:0.099
# INFO 2025-12-13 20:22:07 ot_train.py:351 step:10K smpl:166K ep:250 epch:2.09 loss:0.163 grdn:10.359 lr:1.0e-05 updt_s:0.075 data_s:0.098
# INFO 2025-12-13 20:22:42 ot_train.py:351 step:11K smpl:170K ep:255 epch:2.13 loss:0.165 grdn:10.540 lr:1.0e-05 updt_s:0.075 data_s:0.097
# INFO 2025-12-13 20:23:15 ot_train.py:351 step:11K smpl:173K ep:260 epch:2.17 loss:0.163 grdn:10.474 lr:1.0e-05 updt_s:0.076 data_s:0.093
# INFO 2025-12-13 20:23:50 ot_train.py:351 step:11K smpl:176K ep:265 epch:2.21 loss:0.160 grdn:10.295 lr:1.0e-05 updt_s:0.075 data_s:0.097
# INFO 2025-12-13 20:24:24 ot_train.py:351 step:11K smpl:179K ep:270 epch:2.25 loss:0.159 grdn:10.250 lr:1.0e-05 updt_s:0.075 data_s:0.095
# INFO 2025-12-13 20:24:57 ot_train.py:351 step:11K smpl:182K ep:274 epch:2.29 loss:0.158 grdn:9.846 lr:1.0e-05 updt_s:0.075 data_s:0.092
# INFO 2025-12-13 20:25:31 ot_train.py:351 step:12K smpl:186K ep:279 epch:2.33 loss:0.156 grdn:9.693 lr:1.0e-05 updt_s:0.075 data_s:0.095
# INFO 2025-12-13 20:26:06 ot_train.py:351 step:12K smpl:189K ep:284 epch:2.37 loss:0.152 grdn:9.729 lr:1.0e-05 updt_s:0.075 data_s:0.097
# INFO 2025-12-13 20:26:41 ot_train.py:351 step:12K smpl:192K ep:289 epch:2.41 loss:0.156 grdn:10.081 lr:1.0e-05 updt_s:0.075 data_s:0.098
# INFO 2025-12-13 20:26:41 ot_train.py:361 Checkpoint policy after step 12000
# INFO 2025-12-13 20:27:15 ot_train.py:351 step:12K smpl:195K ep:294 epch:2.45 loss:0.153 grdn:9.394 lr:1.0e-05 updt_s:0.076 data_s:0.092
# INFO 2025-12-13 20:27:50 ot_train.py:351 step:12K smpl:198K ep:298 epch:2.49 loss:0.151 grdn:9.590 lr:1.0e-05 updt_s:0.075 data_s:0.097
# INFO 2025-12-13 20:28:24 ot_train.py:351 step:13K smpl:202K ep:303 epch:2.53 loss:0.148 grdn:9.325 lr:1.0e-05 updt_s:0.075 data_s:0.095
# INFO 2025-12-13 20:28:58 ot_train.py:351 step:13K smpl:205K ep:308 epch:2.57 loss:0.149 grdn:9.162 lr:1.0e-05 updt_s:0.075 data_s:0.095
# INFO 2025-12-13 20:29:32 ot_train.py:351 step:13K smpl:208K ep:313 epch:2.61 loss:0.147 grdn:9.129 lr:1.0e-05 updt_s:0.075 data_s:0.096
# INFO 2025-12-13 20:30:06 ot_train.py:351 step:13K smpl:211K ep:318 epch:2.65 loss:0.146 grdn:9.067 lr:1.0e-05 updt_s:0.074 data_s:0.094
# INFO 2025-12-13 20:30:40 ot_train.py:351 step:13K smpl:214K ep:322 epch:2.69 loss:0.146 grdn:8.895 lr:1.0e-05 updt_s:0.075 data_s:0.097
# INFO 2025-12-13 20:31:15 ot_train.py:351 step:14K smpl:218K ep:327 epch:2.73 loss:0.146 grdn:9.005 lr:1.0e-05 updt_s:0.075 data_s:0.098
# INFO 2025-12-13 20:31:50 ot_train.py:351 step:14K smpl:221K ep:332 epch:2.77 loss:0.141 grdn:8.836 lr:1.0e-05 updt_s:0.075 data_s:0.100
# INFO 2025-12-13 20:32:24 ot_train.py:351 step:14K smpl:224K ep:337 epch:2.81 loss:0.141 grdn:8.814 lr:1.0e-05 updt_s:0.075 data_s:0.095
# INFO 2025-12-13 20:32:24 ot_train.py:361 Checkpoint policy after step 14000
# INFO 2025-12-13 20:32:58 ot_train.py:351 step:14K smpl:227K ep:342 epch:2.85 loss:0.142 grdn:8.518 lr:1.0e-05 updt_s:0.074 data_s:0.090
# INFO 2025-12-13 20:33:32 ot_train.py:351 step:14K smpl:230K ep:347 epch:2.89 loss:0.139 grdn:8.669 lr:1.0e-05 updt_s:0.075 data_s:0.094
# INFO 2025-12-13 20:34:07 ot_train.py:351 step:15K smpl:234K ep:351 epch:2.93 loss:0.140 grdn:8.649 lr:1.0e-05 updt_s:0.075 data_s:0.098
# INFO 2025-12-13 20:34:43 ot_train.py:351 step:15K smpl:237K ep:356 epch:2.97 loss:0.140 grdn:8.843 lr:1.0e-05 updt_s:0.075 data_s:0.105
# INFO 2025-12-13 20:35:22 ot_train.py:351 step:15K smpl:240K ep:361 epch:3.01 loss:0.138 grdn:8.638 lr:1.0e-05 updt_s:0.077 data_s:0.115
# INFO 2025-12-13 20:35:22 ot_train.py:361 Checkpoint policy after step 15000
# INFO 2025-12-13 20:35:23 ot_train.py:430 End of training
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py", line 407, in hf_raise_for_status
#     response.raise_for_status()
#   File "/opt/venv/lib/python3.12/site-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/venv/bin/lerobot-train", line 7, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 444, in main
#     train()
#   File "/workspace/lerobot/src/lerobot/configs/parser.py", line 233, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 434, in train
#     unwrapped_policy.push_model_to_hub(cfg)
#   File "/workspace/lerobot/src/lerobot/policies/pretrained.py", line 211, in push_model_to_hub
#     repo_id = api.create_repo(
#               ^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/hf_api.py", line 3779, in create_repo
#     raise err
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/hf_api.py", line 3766, in create_repo
#     hf_raise_for_status(r)
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py", line 471, in hf_raise_for_status
#     raise _format(HfHubHTTPError, message, response) from e
# huggingface_hub.errors.HfHubHTTPError: (Request ID: Root=1-693dce0b-0ed74daf49027721359c004d;e31428ff-dcd8-4fe1-9eda-2c52f637e3e5)
#
# 403 Forbidden: You don't have the rights to create a model under the namespace "Abubakar17".
# Cannot access content at: https://huggingface.co/api/repos/create.
# Make sure your token has the correct permissions.

# %%
# !huggingface-cli repo create Abubakar17/ext_drop_box --type model
# Out:
# The --type argument is deprecated and will be removed in a future version. Use --repo-type instead.
# ⚠️  Warning: 'huggingface-cli repo' is deprecated. Use 'hf repo' instead.
# Successfully created Abubakar17/ext_drop_box on the Hub.
# Your repo is now available at https://huggingface.co/Abubakar17/ext_drop_box

# %%
from huggingface_hub import login
login(token="token_here")

# %%
from huggingface_hub import HfApi
api = HfApi()
api.upload_folder(
    folder_path="outputs/train/act_so101_mission_2_ext_drop_box_output/checkpoints/015000/pretrained_model",
    repo_id="Abubakar17/ext_drop_box",
    repo_type="model",
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/Abubakar17/ext_drop_box/commit/03c77c98234f0992fd1e9b14e76ec56b501906ec', commit_message='Upload folder using huggingface_hub', commit_description='', oid='03c77c98234f0992fd1e9b14e76ec56b501906ec', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Abubakar17/ext_drop_box', endpoint='https://huggingface.co', repo_type='model', repo_id='Abubakar17/ext_drop_box'), pr_revision=None, pr_num=None)

# %%
# !lerobot-train \
  --dataset.repo_id=Abubakar17/mission_2_drop_tape \
  --batch_size=16 \
  --steps=13500 \
  --output_dir=outputs/train/act_so101_mission_2_ext_drop_tape_output \
  --job_name=act_so101_mission_2_ext_drop_tape_job \
  --policy.repo_id=Abubakar17/ext_drop_tape \
  --policy.device=cuda \
  --policy.type=act \
  --policy.push_to_hub=true \
  --wandb.enable=true  \
  --dataset.image_transforms.enable=True  \
  --save_freq=2000  \
  --eval_freq=5000
# Out:
# INFO 2025-12-14 00:06:01 ot_train.py:163 {'batch_size': 16,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': True,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'Abubakar17/mission_2_drop_tape',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 5000,
#  'job_name': 'act_so101_mission_2_ext_drop_tape_job',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_so101_mission_2_ext_drop_tape_output',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': 'Abubakar17/ext_drop_tape',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 2000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 13500,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /opt/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /opt/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2025-12-14 00:06:02 db_utils.py:102 Logs will be synced with wandb.
# INFO 2025-12-14 00:06:02 db_utils.py:103 Track this run --> https://wandb.ai/syedabubakar03-universit-de-technologie-de-compi-gne/lerobot/runs/nrddspvs
# INFO 2025-12-14 00:06:02 ot_train.py:183 Creating dataset
# INFO 2025-12-14 00:06:03 ot_train.py:202 Creating policy
# INFO 2025-12-14 00:06:03 ot_train.py:247 Creating optimizer and scheduler
# INFO 2025-12-14 00:06:03 ot_train.py:259 Output dir: outputs/train/act_so101_mission_2_ext_drop_tape_output
# INFO 2025-12-14 00:06:03 ot_train.py:262 cfg.steps=13500 (14K)
# INFO 2025-12-14 00:06:03 ot_train.py:263 dataset.num_frames=20102 (20K)
# INFO 2025-12-14 00:06:03 ot_train.py:264 dataset.num_episodes=40
# INFO 2025-12-14 00:06:03 ot_train.py:267 Effective batch size: 16 x 1 = 16
# INFO 2025-12-14 00:06:03 ot_train.py:268 num_learnable_params=51597190 (52M)
# INFO 2025-12-14 00:06:03 ot_train.py:269 num_total_params=51597190 (52M)
# INFO 2025-12-14 00:06:03 ot_train.py:324 Start offline training on a fixed dataset
# INFO 2025-12-14 00:06:58 ot_train.py:351 step:200 smpl:3K ep:6 epch:0.16 loss:6.083 grdn:114.152 lr:1.0e-05 updt_s:0.176 data_s:0.097
# INFO 2025-12-14 00:07:32 ot_train.py:351 step:400 smpl:6K ep:13 epch:0.32 loss:2.594 grdn:59.838 lr:1.0e-05 updt_s:0.074 data_s:0.094
# INFO 2025-12-14 00:08:06 ot_train.py:351 step:600 smpl:10K ep:19 epch:0.48 loss:2.142 grdn:54.504 lr:1.0e-05 updt_s:0.074 data_s:0.094
# INFO 2025-12-14 00:08:39 ot_train.py:351 step:800 smpl:13K ep:25 epch:0.64 loss:1.822 grdn:50.566 lr:1.0e-05 updt_s:0.073 data_s:0.095
# INFO 2025-12-14 00:09:13 ot_train.py:351 step:1K smpl:16K ep:32 epch:0.80 loss:1.596 grdn:47.182 lr:1.0e-05 updt_s:0.074 data_s:0.093
# INFO 2025-12-14 00:09:47 ot_train.py:351 step:1K smpl:19K ep:38 epch:0.96 loss:1.410 grdn:44.785 lr:1.0e-05 updt_s:0.073 data_s:0.098
# INFO 2025-12-14 00:10:27 ot_train.py:351 step:1K smpl:22K ep:45 epch:1.11 loss:1.242 grdn:42.697 lr:1.0e-05 updt_s:0.096 data_s:0.102
# INFO 2025-12-14 00:11:01 ot_train.py:351 step:2K smpl:26K ep:51 epch:1.27 loss:1.095 grdn:38.870 lr:1.0e-05 updt_s:0.073 data_s:0.100
# INFO 2025-12-14 00:11:35 ot_train.py:351 step:2K smpl:29K ep:57 epch:1.43 loss:0.967 grdn:37.076 lr:1.0e-05 updt_s:0.075 data_s:0.093
# INFO 2025-12-14 00:12:08 ot_train.py:351 step:2K smpl:32K ep:64 epch:1.59 loss:0.854 grdn:33.998 lr:1.0e-05 updt_s:0.073 data_s:0.091
# INFO 2025-12-14 00:12:08 ot_train.py:361 Checkpoint policy after step 2000
# INFO 2025-12-14 00:12:42 ot_train.py:351 step:2K smpl:35K ep:70 epch:1.75 loss:0.754 grdn:31.994 lr:1.0e-05 updt_s:0.073 data_s:0.088
# INFO 2025-12-14 00:13:15 ot_train.py:351 step:2K smpl:38K ep:76 epch:1.91 loss:0.672 grdn:30.549 lr:1.0e-05 updt_s:0.073 data_s:0.094
# INFO 2025-12-14 00:13:51 ot_train.py:351 step:3K smpl:42K ep:83 epch:2.07 loss:0.597 grdn:28.386 lr:1.0e-05 updt_s:0.073 data_s:0.105
# INFO 2025-12-14 00:14:25 ot_train.py:351 step:3K smpl:45K ep:89 epch:2.23 loss:0.531 grdn:26.604 lr:1.0e-05 updt_s:0.073 data_s:0.098
# INFO 2025-12-14 00:15:00 ot_train.py:351 step:3K smpl:48K ep:96 epch:2.39 loss:0.480 grdn:24.848 lr:1.0e-05 updt_s:0.073 data_s:0.097
# INFO 2025-12-14 00:15:34 ot_train.py:351 step:3K smpl:51K ep:102 epch:2.55 loss:0.438 grdn:23.582 lr:1.0e-05 updt_s:0.074 data_s:0.098
# INFO 2025-12-14 00:16:08 ot_train.py:351 step:3K smpl:54K ep:108 epch:2.71 loss:0.401 grdn:22.451 lr:1.0e-05 updt_s:0.073 data_s:0.096
# INFO 2025-12-14 00:16:43 ot_train.py:351 step:4K smpl:58K ep:115 epch:2.87 loss:0.372 grdn:21.117 lr:1.0e-05 updt_s:0.074 data_s:0.099
# INFO 2025-12-14 00:17:20 ot_train.py:351 step:4K smpl:61K ep:121 epch:3.02 loss:0.345 grdn:20.192 lr:1.0e-05 updt_s:0.074 data_s:0.110
# INFO 2025-12-14 00:17:55 ot_train.py:351 step:4K smpl:64K ep:127 epch:3.18 loss:0.323 grdn:19.927 lr:1.0e-05 updt_s:0.073 data_s:0.103
# INFO 2025-12-14 00:17:55 ot_train.py:361 Checkpoint policy after step 4000
# INFO 2025-12-14 00:18:30 ot_train.py:351 step:4K smpl:67K ep:134 epch:3.34 loss:0.307 grdn:19.242 lr:1.0e-05 updt_s:0.074 data_s:0.094
# INFO 2025-12-14 00:19:05 ot_train.py:351 step:4K smpl:70K ep:140 epch:3.50 loss:0.289 grdn:18.423 lr:1.0e-05 updt_s:0.074 data_s:0.104
# INFO 2025-12-14 00:19:41 ot_train.py:351 step:5K smpl:74K ep:146 epch:3.66 loss:0.281 grdn:18.079 lr:1.0e-05 updt_s:0.075 data_s:0.105
# INFO 2025-12-14 00:20:16 ot_train.py:351 step:5K smpl:77K ep:153 epch:3.82 loss:0.270 grdn:17.884 lr:1.0e-05 updt_s:0.073 data_s:0.101
# INFO 2025-12-14 00:20:51 ot_train.py:351 step:5K smpl:80K ep:159 epch:3.98 loss:0.255 grdn:16.899 lr:1.0e-05 updt_s:0.073 data_s:0.102
# INFO 2025-12-14 00:21:27 ot_train.py:351 step:5K smpl:83K ep:166 epch:4.14 loss:0.249 grdn:16.525 lr:1.0e-05 updt_s:0.074 data_s:0.106
# INFO 2025-12-14 00:22:03 ot_train.py:351 step:5K smpl:86K ep:172 epch:4.30 loss:0.238 grdn:15.565 lr:1.0e-05 updt_s:0.073 data_s:0.103
# INFO 2025-12-14 00:22:38 ot_train.py:351 step:6K smpl:90K ep:178 epch:4.46 loss:0.233 grdn:15.416 lr:1.0e-05 updt_s:0.073 data_s:0.102
# INFO 2025-12-14 00:23:13 ot_train.py:351 step:6K smpl:93K ep:185 epch:4.62 loss:0.223 grdn:15.328 lr:1.0e-05 updt_s:0.073 data_s:0.104
# INFO 2025-12-14 00:23:49 ot_train.py:351 step:6K smpl:96K ep:191 epch:4.78 loss:0.221 grdn:15.487 lr:1.0e-05 updt_s:0.074 data_s:0.101
# INFO 2025-12-14 00:23:49 ot_train.py:361 Checkpoint policy after step 6000
# INFO 2025-12-14 00:24:24 ot_train.py:351 step:6K smpl:99K ep:197 epch:4.93 loss:0.213 grdn:14.705 lr:1.0e-05 updt_s:0.073 data_s:0.095
# INFO 2025-12-14 00:25:00 ot_train.py:351 step:6K smpl:102K ep:204 epch:5.09 loss:0.210 grdn:14.834 lr:1.0e-05 updt_s:0.074 data_s:0.107
# INFO 2025-12-14 00:25:33 ot_train.py:351 step:7K smpl:106K ep:210 epch:5.25 loss:0.205 grdn:14.049 lr:1.0e-05 updt_s:0.073 data_s:0.094
# INFO 2025-12-14 00:26:08 ot_train.py:351 step:7K smpl:109K ep:216 epch:5.41 loss:0.200 grdn:13.916 lr:1.0e-05 updt_s:0.073 data_s:0.097
# INFO 2025-12-14 00:26:41 ot_train.py:351 step:7K smpl:112K ep:223 epch:5.57 loss:0.194 grdn:13.761 lr:1.0e-05 updt_s:0.073 data_s:0.092
# INFO 2025-12-14 00:27:14 ot_train.py:351 step:7K smpl:115K ep:229 epch:5.73 loss:0.193 grdn:13.794 lr:1.0e-05 updt_s:0.073 data_s:0.094
# INFO 2025-12-14 00:27:48 ot_train.py:351 step:7K smpl:118K ep:236 epch:5.89 loss:0.187 grdn:13.032 lr:1.0e-05 updt_s:0.074 data_s:0.095
# INFO 2025-12-14 00:28:24 ot_train.py:351 step:8K smpl:122K ep:242 epch:6.05 loss:0.182 grdn:13.059 lr:1.0e-05 updt_s:0.073 data_s:0.103
# INFO 2025-12-14 00:28:59 ot_train.py:351 step:8K smpl:125K ep:248 epch:6.21 loss:0.178 grdn:12.839 lr:1.0e-05 updt_s:0.073 data_s:0.104
# INFO 2025-12-14 00:29:34 ot_train.py:351 step:8K smpl:128K ep:255 epch:6.37 loss:0.178 grdn:12.654 lr:1.0e-05 updt_s:0.073 data_s:0.101
# INFO 2025-12-14 00:29:34 ot_train.py:361 Checkpoint policy after step 8000
# INFO 2025-12-14 00:30:10 ot_train.py:351 step:8K smpl:131K ep:261 epch:6.53 loss:0.174 grdn:12.481 lr:1.0e-05 updt_s:0.074 data_s:0.096
# INFO 2025-12-14 00:30:44 ot_train.py:351 step:8K smpl:134K ep:267 epch:6.69 loss:0.172 grdn:12.566 lr:1.0e-05 updt_s:0.073 data_s:0.100
# INFO 2025-12-14 00:31:19 ot_train.py:351 step:9K smpl:138K ep:274 epch:6.85 loss:0.169 grdn:12.181 lr:1.0e-05 updt_s:0.073 data_s:0.099
# INFO 2025-12-14 00:31:54 ot_train.py:351 step:9K smpl:141K ep:280 epch:7.00 loss:0.168 grdn:12.127 lr:1.0e-05 updt_s:0.074 data_s:0.102
# INFO 2025-12-14 00:32:28 ot_train.py:351 step:9K smpl:144K ep:287 epch:7.16 loss:0.163 grdn:12.027 lr:1.0e-05 updt_s:0.073 data_s:0.098
# INFO 2025-12-14 00:33:03 ot_train.py:351 step:9K smpl:147K ep:293 epch:7.32 loss:0.161 grdn:11.665 lr:1.0e-05 updt_s:0.073 data_s:0.099
# INFO 2025-12-14 00:33:37 ot_train.py:351 step:9K smpl:150K ep:299 epch:7.48 loss:0.158 grdn:11.225 lr:1.0e-05 updt_s:0.073 data_s:0.099
# INFO 2025-12-14 00:34:12 ot_train.py:351 step:10K smpl:154K ep:306 epch:7.64 loss:0.154 grdn:11.282 lr:1.0e-05 updt_s:0.073 data_s:0.100
# INFO 2025-12-14 00:34:46 ot_train.py:351 step:10K smpl:157K ep:312 epch:7.80 loss:0.155 grdn:11.482 lr:1.0e-05 updt_s:0.073 data_s:0.096
# INFO 2025-12-14 00:35:21 ot_train.py:351 step:10K smpl:160K ep:318 epch:7.96 loss:0.153 grdn:10.903 lr:1.0e-05 updt_s:0.073 data_s:0.102
# INFO 2025-12-14 00:35:21 ot_train.py:361 Checkpoint policy after step 10000
# INFO 2025-12-14 00:35:59 ot_train.py:351 step:10K smpl:163K ep:325 epch:8.12 loss:0.148 grdn:11.012 lr:1.0e-05 updt_s:0.074 data_s:0.106
# INFO 2025-12-14 00:36:35 ot_train.py:351 step:10K smpl:166K ep:331 epch:8.28 loss:0.145 grdn:10.543 lr:1.0e-05 updt_s:0.073 data_s:0.106
# INFO 2025-12-14 00:37:10 ot_train.py:351 step:11K smpl:170K ep:337 epch:8.44 loss:0.144 grdn:10.789 lr:1.0e-05 updt_s:0.073 data_s:0.105
# INFO 2025-12-14 00:37:46 ot_train.py:351 step:11K smpl:173K ep:344 epch:8.60 loss:0.146 grdn:10.912 lr:1.0e-05 updt_s:0.073 data_s:0.103
# INFO 2025-12-14 00:38:19 ot_train.py:351 step:11K smpl:176K ep:350 epch:8.76 loss:0.142 grdn:10.265 lr:1.0e-05 updt_s:0.073 data_s:0.094
# INFO 2025-12-14 00:38:53 ot_train.py:351 step:11K smpl:179K ep:357 epch:8.91 loss:0.144 grdn:10.515 lr:1.0e-05 updt_s:0.073 data_s:0.093
# INFO 2025-12-14 00:39:28 ot_train.py:351 step:11K smpl:182K ep:363 epch:9.07 loss:0.138 grdn:10.357 lr:1.0e-05 updt_s:0.074 data_s:0.103
# INFO 2025-12-14 00:40:02 ot_train.py:351 step:12K smpl:186K ep:369 epch:9.23 loss:0.137 grdn:10.244 lr:1.0e-05 updt_s:0.073 data_s:0.098
# INFO 2025-12-14 00:40:36 ot_train.py:351 step:12K smpl:189K ep:376 epch:9.39 loss:0.137 grdn:10.083 lr:1.0e-05 updt_s:0.073 data_s:0.095
# INFO 2025-12-14 00:41:09 ot_train.py:351 step:12K smpl:192K ep:382 epch:9.55 loss:0.135 grdn:10.089 lr:1.0e-05 updt_s:0.073 data_s:0.095
# INFO 2025-12-14 00:41:09 ot_train.py:361 Checkpoint policy after step 12000
# INFO 2025-12-14 00:41:43 ot_train.py:351 step:12K smpl:195K ep:388 epch:9.71 loss:0.133 grdn:9.758 lr:1.0e-05 updt_s:0.073 data_s:0.086
# INFO 2025-12-14 00:42:15 ot_train.py:351 step:12K smpl:198K ep:395 epch:9.87 loss:0.130 grdn:9.405 lr:1.0e-05 updt_s:0.073 data_s:0.088
# INFO 2025-12-14 00:42:50 ot_train.py:351 step:13K smpl:202K ep:401 epch:10.03 loss:0.129 grdn:9.488 lr:1.0e-05 updt_s:0.073 data_s:0.101
# INFO 2025-12-14 00:43:22 ot_train.py:351 step:13K smpl:205K ep:408 epch:10.19 loss:0.126 grdn:9.609 lr:1.0e-05 updt_s:0.075 data_s:0.086
# INFO 2025-12-14 00:43:55 ot_train.py:351 step:13K smpl:208K ep:414 epch:10.35 loss:0.131 grdn:9.720 lr:1.0e-05 updt_s:0.073 data_s:0.090
# INFO 2025-12-14 00:44:28 ot_train.py:351 step:13K smpl:211K ep:420 epch:10.51 loss:0.126 grdn:9.305 lr:1.0e-05 updt_s:0.073 data_s:0.090
# INFO 2025-12-14 00:45:01 ot_train.py:351 step:13K smpl:214K ep:427 epch:10.67 loss:0.126 grdn:8.993 lr:1.0e-05 updt_s:0.073 data_s:0.095
# INFO 2025-12-14 00:45:18 ot_train.py:361 Checkpoint policy after step 13500
# INFO 2025-12-14 00:45:19 ot_train.py:430 End of training
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...op_tape/model.safetensors:   0%|              |  782kB /  207MB
#
# Processing Files (0 / 1)      :   0%|              |  782kB /  207MB, 3.91MB/s
#
# Processing Files (0 / 1)      :   1%|▏             | 3.04MB /  207MB, 7.60MB/s
# New Data Upload               :   3%|▍             | 2.26MB / 67.1MB, 5.65MB/s
#
# Processing Files (0 / 1)      :  15%|██            | 30.1MB /  207MB, 50.2MB/s
# New Data Upload               :  22%|███           | 29.3MB /  134MB, 48.9MB/s
#
# Processing Files (0 / 1)      :  38%|█████▍        | 79.6MB /  207MB, 99.5MB/s
# New Data Upload               :  38%|█████▎        | 78.7MB /  206MB, 98.5MB/s
#
# Processing Files (0 / 1)      :  66%|█████████▎    |  137MB /  207MB,  137MB/s
# New Data Upload               :  66%|█████████▎    |  136MB /  206MB,  136MB/s
#
# Processing Files (0 / 1)      :  92%|████████████▉ |  191MB /  207MB,  159MB/s
# New Data Upload               :  92%|████████████▉ |  190MB /  206MB,  158MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉|  206MB /  207MB,  147MB/s
# New Data Upload               : 100%|█████████████▉|  206MB /  206MB,  147MB/s
#
# Processing Files (0 / 1)      : 100%|█████████████▉|  206MB /  207MB,  129MB/s
# New Data Upload               : 100%|█████████████▉|  206MB /  206MB,  129MB/s
#
#   ...op_tape/model.safetensors: 100%|█████████████▉|  206MB /  207MB
#
# Processing Files (1 / 1)      : 100%|██████████████|  207MB /  207MB,  103MB/s
# New Data Upload               : 100%|██████████████|  206MB /  206MB,  103MB/s
#
#   ...op_tape/model.safetensors: 100%|██████████████|  207MB /  207MB
#
#   ...op_tape/model.safetensors: 100%|██████████████|  207MB /  207MB
#
# Processing Files (1 / 1)      : 100%|██████████████|  207MB /  207MB, 86.1MB/s
# New Data Upload               : 100%|██████████████|  206MB /  206MB, 85.8MB/s
#   ...op_tape/model.safetensors: 100%|██████████████|  207MB /  207MB
# INFO 2025-12-14 00:45:24 etrained.py:237 Model pushed to https://huggingface.co/Abubakar17/ext_drop_tape
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.52kB / 7.52kB,  0.00B/s
# New Data Upload               : |                  |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.52kB / 7.52kB,   ???B/s
#
# Processing Files (1 / 1)      : 100%|██████████████| 7.52kB / 7.52kB,  0.00B/s
# New Data Upload               : |                  |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100%|██████████████| 7.52kB / 7.52kB

# %% [markdown]
# ## Download Models from Hugging Face to Local Machine
# Now after training is done, download the model to local machine.

# %%
# !huggingface-cli download ${HF_USER}/{REPO_NAME} --repo-type model --local-dir path/to/model
# e.g. huggingface-cli upload ${HF_USER}/act_so101_3cube_1ksteps \
#  outputs/train/act_so101_3cube_1ksteps/checkpoints/last/pretrained_model

# %% [markdown]
# ## Miscs
# 1. Once the environment is setup, you can open a terminal session for training by navigating to `File → New Launcher → Other → Terminal`.
# 2. You can also upload your datasets to the container by clicking the `Upload Files` button in the left pane.

# %% [markdown]
# ## Q&A
# 1. If you encounter an error like:
#    ```
#    FileExistsError: Output directory outputs/train/act_so101_3cube_1ksteps already exists and resume is False. Please change your output directory so that outputs/train/act_so101_3cube_1ksteps is not overwritten.
#    ```
#    Remove the existing directory before proceeding:

# %%
# !rm -fr outputs/train/act_so101_3cube_1ksteps

# %% [markdown]
# 2. When running models other than ACT, ensure you install the required additional dependencies for those models.

# %%
# For smolVLA
# !cd lerobot && pip install -e ".[smolvla]"
# For Pi
# !cd lerobot && pip install -e ".[pi]"

# %% [markdown]
# 3. If you want to resume the training from last checkpoint, run the command below:

# %%
# !lerobot-train \
  --resume=true \
  --config_path=outputs/train/<job name>/checkpoints/last/pretrained_model/train_config.json \
  --steps=<new total steps>

# %% [markdown]
# 4. If you want to upload your dataset using `huggingface-cli upload <repo name> <path to the dataset> --repo-type=dataset`, be sure to set a codebase tag like below:

# %%
from huggingface_hub import HfApi
from huggingface_hub import login

login(token="your_huggingface_token")
hub_api = HfApi()
hub_api.create_tag(<HF_REPO_NAME>, tag="v3.0", revision="main", repo_type="dataset")
